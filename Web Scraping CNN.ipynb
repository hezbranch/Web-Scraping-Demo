# %% [markdown]
# ## Web Scraping Demo
#
# Hezekiah Branch
#
# Thu Jan 6 2022
#
# **Goal: Scraping list of articles from the current CNN homepage**
#
#
# First two cells from https://realpython.com/python-web-scraping-practical-introduction/

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import json
import time

# %%
# Begin wall-timing workflow for web scraping
start = time.time()

# %% [markdown]
# Make an HTTP request to the CNN server where the connection closing is handled by urllib.
#
# Parse the HTML using BeautifulSoup.

# %%
url = "https://www.cnn.com"
page = urlopen(url)
html = page.read().decode("utf-8")
soup = BeautifulSoup(html, "html.parser")

# %%
# I outputted 'get_text()' to express the need
# for more "hacking" on the developer side
# since this output is not the content we want
# from the home page (i.e. trending articles)
print(soup.get_text())
# Out:
# CNN - Breaking News, Latest News and Videos
#
#
# USWorldPoliticsBusinessOpinionHealthEntertainmentStyleTravelSportsVideosEditionU.S.InternationalArabicEspañolSearch CNNOpen MenuSearchEditionU.S.InternationalArabicEspañolUSCrime + JusticeEnergy + EnvironmentExtreme WeatherSpace + ScienceWorldAfricaAmericasAsiaAustraliaChinaEuropeIndiaMiddle EastUnited KingdomPoliticsThe Biden PresidencyFacts FirstUS ElectionsBusinessMarketsTechMediaSuccessPerspectivesVideosOpinionPolitical Op-EdsSocial CommentaryHealthLife, But BetterFitnessFoodSleepMindfulnessRelationshipsEntertainmentStarsScreenBingeCultureMediaTechInnovateGadgetForeseeable FutureMission: AheadUpstartsWork TransformedInnovative CitiesStyleArtsDesignFashionArchitectureLuxuryBeautyVideoTravelDestinationsFood and DrinkStayNewsVideosSportsPro FootballCollege FootballBasketballBaseballSoccerOlympicsHockeyVideosLive TV Digital StudiosCNN FilmsHLNTV ScheduleTV Shows A-ZCNNVRAudioCouponsCNN UnderscoredExploreWellnessGadgetsLifestyleCNN StoreWeatherClimateStorm TrackerWildfire TrackerVideoMorePhotosLongformInvestigationsCNN ProfilesCNN LeadershipCNN NewslettersWork for CNNFollow CNN
#
#
#
#
#
# SearchUSCrime + JusticeEnergy + EnvironmentExtreme WeatherSpace + ScienceWorldAfricaAmericasAsiaAustraliaChinaEuropeIndiaMiddle EastUnited KingdomPoliticsThe Biden PresidencyFacts FirstUS ElectionsBusinessMarketsTechMediaSuccessPerspectivesVideosOpinionPolitical Op-EdsSocial CommentaryHealthLife, But BetterFitnessFoodSleepMindfulnessRelationshipsEntertainmentStarsScreenBingeCultureMediaTechInnovateGadgetForeseeable FutureMission: AheadUpstartsWork TransformedInnovative CitiesStyleArtsDesignFashionArchitectureLuxuryBeautyVideoTravelDestinationsFood and DrinkStayNewsVideosSportsPro FootballCollege FootballBasketballBaseballSoccerOlympicsHockeyVideosLive TV Digital StudiosCNN FilmsHLNTV ScheduleTV Shows A-ZCNNVRAudioCouponsCNN UnderscoredExploreWellnessGadgetsLifestyleCNN StoreWeatherClimateStorm TrackerWildfire TrackerVideoMorePhotosLongformInvestigationsCNN ProfilesCNN LeadershipCNN NewslettersWork for CNNFollow CNN Terms of UsePrivacy PolicyAccessibility & CCAd ChoicesAbout UsCNN StoreNewslettersTranscriptsLicense FootageCNN NewsourceSitemap© 2022 Cable News Network.A Warner Media Company.All Rights Reserved.CNN Sans ™ & © 2016 Cable News Network.

# %% [markdown]
# We can get a structured string with BeautifulSoup's 'prettify' function, which we then turn into a list.
#
# The prettify output separated each HTML tag on a new line, so we can use '\n' as our delimiter to turn this string into a list/array.

# %%
pretty_soup = soup.prettify()

# %%
pretty_bowl = pretty_soup.split('\n')
pretty_bowl[0:50]
# Out:
# ['<!DOCTYPE html>',
#  '<html class="no-js">',
#  ' <head>',
#  '  <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>',
#  '  <meta charset="utf-8"/>',
#  '  <meta content="text/html" http-equiv="Content-Type"/>',
#  '  <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>',
#  '  <link href="/optimizelyjs/131788053.js" rel="dns-prefetch"/>',
#  '  <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>',
#  '  <link href="//pagead2.googlesyndication.com" rel="dns-prefetch"/>',
#  '  <link href="//www.googletagservices.com" rel="dns-prefetch"/>',
#  '  <link href="//partner.googleadservices.com" rel="dns-prefetch"/>',
#  '  <link href="//www.google.com" rel="dns-prefetch"/>',
#  '  <link href="//aax.amazon-adsystem.com" rel="dns-prefetch"/>',
#  '  <link href="//c.amazon-adsystem.com" rel="dns-prefetch"/>',
#  '  <link href="//cdn.krxd.net" rel="dns-prefetch"/>',
#  '  <link href="//ads.rubiconproject.com" rel="dns-prefetch"/>',
#  '  <link href="//optimized-by.rubiconproject.com" rel="dns-prefetch"/>',
#  '  <link href="//fastlane.rubiconproject.com" rel="dns-prefetch"/>',
#  '  <link href="//fastlane-adv.rubiconproject.com" rel="dns-prefetch"/>',
#  '  <link href="”//ib.adnxs.com”/" rel="dns-prefetch"/>',
#  '  <link href="”//prebid.adnxs.com”/" rel="dns-prefetch"/>',
#  '  <link href="http://segment-data-us-east.zqtk.net/turner-47fcf6" rel="dns-prefetch">',
#  '   <link href="//static.yieldmo.com" rel="dns-prefetch">',
#  '    <link href="//w.usabilla.com" rel="dns-prefetch"/>',
#  '    <link href="" rel="dns-prefetch"/>',
#  '    <link href="//data.api.cnn.io" rel="dns-prefetch"/>',
#  '    <link href="//pmd.cdn.turner.com" rel="dns-prefetch"/>',
#  '    <link href="//amd.cdn.turner.com" rel="dns-prefetch"/>',
#  '    <link href="//ht.cdn.turner.com" rel="dns-prefetch"/>',
#  '    <link href="//www.ugdturner.com" rel="dns-prefetch"/>',
#  '    <link href="//vrt.outbrain.com" rel="dns-prefetch"/>',
#  '    <link href="//consent.truste.com" rel="dns-prefetch"/>',
#  '    <link href="//as.casalemedia.com" rel="dns-prefetch"/>',
#  '    <link href="//as-sec.casalemedia.com" rel="dns-prefetch"/>',
#  '    <link href="//dsum-sec.casalemedia.com" rel="dns-prefetch"/>',
#  '    <link href="//js-sec.indexww.com" rel="dns-prefetch"/>',
#  '    <link href="//data.cnn.com" rel="dns-prefetch"/>',
#  '    <link href="//cdn.cnn.com" rel="dns-prefetch"/>',
#  '    <link href="//www.i.cdn.cnn.com" rel="dns-prefetch"/>',
#  '    <link as="fetch" crossorigin="anonymous" href="//cdn.cnn.com/ads/cnn/cnn_homepage.json" rel="preload" type="application/json"/>',
#  '    <link as="script" href="/.a/bundles/header.82f0a1272663c09179fe.bundle.js" rel="preload" type="application/javascript"/>',
#  '    <link as="script" href="https://www.googletagservices.com/tag/js/gpt.js" rel="preload" type="text/javascript"/>',
#  '    <link as="script" href="https://c.amazon-adsystem.com/aax2/apstag.js" rel="preload" type="application/javascript"/>',
#  '    <link as="script" href="/.a/2.283.0/js/cnn-header-second-react.min.js" rel="preload" type="application/javascript"/>',
#  '    <link as="script" href="/optimizelyjs/131788053.js" rel="preload" type="text/javascript"/>',
#  '    <link as="script" href="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" rel="preload" type="application/javascript"/>',
#  '    <link as="font" crossorigin="anonymous" href="//www.i.cdn.cnn.com/.a/fonts/cnn/3.9.0/cnnsans-regular.woff2" rel="preload" type="font/woff2"/>',
#  '    <link as="font" crossorigin="anonymous" href="//www.i.cdn.cnn.com/.a/fonts/cnn/3.9.0/cnnsans-lightit.woff2" rel="preload" type="font/woff2"/>',
#  '    <link as="font" crossorigin="anonymous" href="//www.i.cdn.cnn.com/.a/fonts/cnn/3.9.0/cnnsans-italic.woff2" rel="preload" type="font/woff2"/>']

# %% [markdown]
# Since we are dealing with article data, we only want the lines associated with article data.
#
# We can use these tags to subset the amount of string we are looking at. Most importantly, without needing to know what string formatting the CNN HTML uses in advance. The last line shows a small preview of what the output looks like. It's not necessary to keep it unless you really need it.

# %%
tags = ['subTitle', 'name', 'title', 'headline', 'description', 'src', 'mpId']

# %%
subset = []

for row in pretty_bowl:
    valid = True
    for tag in tags:
        if tag not in row:
            valid = False
    if valid:
        subset.append(row)
        
subset[0][0:500]
# Out:
# '         window.CNN = window.CNN || {};window.CNNI = window.CNNI || {},window.FAVE = window.FAVE || {};window.WM = window.WM || {};window.document.domain = \'cnn.com\';if (typeof window.console === \'undefined\') {window.console = {debug: function() {return true;},error: function() {return true;},info: function() {return false;},warn: function() {return false;},log: function() {return false;},timeStamp: function() {return false;}}}CNN.isWebview = false;CNN.adTargets = {protocol: "ssl"};CNN.AdsConfig'

# %% [markdown]
# Having found our (naively) most important subset of the string, we can more precisely extract the list of articles.

# %%
len(subset) # start at "values:" end at "}]}"
# Out:
# 1

# %%
start_text = "{\"articleList\":"
start_index = subset[0].find(start_text) + len(start_text)

end_text = "\"layout\":\"\"}]"
end_index = subset[0].find(end_text) + len(end_text) # The 'find' module gives the start, NOT the end

print(start_index)
print(end_index)
# Out:
# 105806
# 131848

# %%
article_list = subset[0][start_index:end_index]
article_list[0:500]
# Out:
# '[{"uri":"/2022/01/06/politics/joe-biden-january-6-speech-anniversary/index.html","headline":"\\u003cstrong>It\'s likely to be the line repeated most today and in days to come\\u003c/strong>","thumbnail":"//cdn.cnn.com/cnnnext/dam/assets/220106093419-03-biden-jan-6-speech-small-11.jpg","duration":"","description":"","layout":""},{"uri":"/2022/01/06/politics/january-6-anniversary/index.html","headline":"Biden condemns Trump as a threat to democracy","thumbnail":"//cdn.cnn.com/cnnnext/dam/assets/22010'

# %% [markdown]
# We then load this string into JSON to get a preferred JSON object of articles.

# %%
data = json.loads(article_list)
data
# Out:
# [{'uri': '/2022/01/06/politics/joe-biden-january-6-speech-anniversary/index.html',
#   'headline': "<strong>It's likely to be the line repeated most today and in days to come</strong>",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220106093419-03-biden-jan-6-speech-small-11.jpg',
#   'duration': '',
#   'description': '',
#   'layout': ''},
#  {'uri': '/2022/01/06/politics/january-6-anniversary/index.html',
#   'headline': 'Biden condemns Trump as a threat to democracy',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220106092029-02-biden-jan-6-speech-small-11.jpg',
#   'duration': '',
#   'description': '<a href="https://www.cnn.com/specials/politics/joe-biden-news" target="_blank">President Joe Biden</a> on Thursday marked the first anniversary of the January 6 insurrection by forcefully calling out former President Donald Trump for attempting to undo American democracy, saying such an insurrection must never happen again.',
#   'layout': ''},
#  {'uri': '/videos/politics/2022/01/06/stephanie-grisham-donald-trump-ego-newday-vpx.cnn',
#   'headline': "Ex-Trump aide describes the worry with Trump's 'fragile ego'",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220106091107-stephanie-grisham-donald-trump-small-11.jpg',
#   'duration': '01:50',
#   'description': 'Stephanie Grisham, former communications director and press secretary for the Trump administration, talks to New Day after speaking with the House Select Committee on January 6, about what she and other former Trump staff and administration officials are planning to do to stop the former President.',
#   'layout': '',
#   'iconType': 'video'},
#  {'uri': '/2022/01/06/opinions/what-i-saw-on-january-6-chideya/index.html',
#   'headline': "<strong>Opinion:</strong> I was there on January 6. Here's what I've learned in the year since",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220106052132-child-stop-the-steal-penn-file-11052020-small-11.jpg',
#   'duration': '',
#   'description': 'On January 6, 2021, I left the Maryland suburbs and drove to downtown Washington, DC for the "Stop the Steal" rally. ',
#   'layout': ''},
#  {'uri': '/2022/01/06/politics/stephanie-grisham-trump-officials-meeting-cnntv/index.html',
#   'headline': "Stephanie Grisham says group of ex-Trump officials to meet next week to discuss how to 'stop' him",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/200407100829-stephanie-grisham-trump-file-small-11.jpg',
#   'duration': '',
#   'description': 'Former White House press secretary <a href="https://www.cnn.com/2022/01/05/politics/stephanie-grisham-committee-meeting/index.html" target="_blank">Stephanie Grisham</a> said Thursday that more than a dozen of her former Trump administration colleagues plan to meet next week to try and stop former President Donald Trump as he continues to "manipulate people and divide our country."',
#   'layout': ''},
#  {'uri': '/2022/01/06/opinions/president-biden-speech-democracy-warrior-ghitis/index.html',
#   'headline': "<strong>Opinion</strong>: Biden assumes role of America's democracy warrior",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220106093511-04-biden-jan-6-speech-small-11.jpg',
#   'duration': '',
#   'description': 'President Joe Biden, marking the anniversary of the January 6 attack at the US Capitol, delivered the <a href="https://www.cnn.com/videos/politics/2022/01/06/president-joe-biden-january-6th-anniversary-trump-defeated-remarks-vpx.cnn" target="_blank">most powerful, blistering speech</a> of his presidency thus far, signaling a stark shift in his approach to the nation\'s ongoing crisis of democracy.',
#   'layout': ''},
#  {'uri': '/2022/01/06/politics/trump-tweet-january-6/index.html',
#   'headline': "<strong>Trump did not want to tweet 'stay peaceful' during January 6 riot, key former aide says</strong>",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220106084508-capitol-reality-check-01062022-small-11.jpg',
#   'duration': '',
#   'description': '',
#   'layout': ''},
#  {'uri': '/videos/politics/2022/01/06/senator-joe-neguse-experience-evacuating-insurrection-king-intv-vpx.cnn',
#   'headline': 'Senator shares defining moment from January 6',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/210210131744-rep-joe-neguse-0210-small-11.jpg',
#   'duration': '01:54',
#   'description': 'Sen. Joe Neguse (D-CO) joins Inside Politics to discuss his experience last year when he was evacuated from the senate floor during the insurrection.',
#   'layout': '',
#   'iconType': 'video'},
#  {'uri': '/2022/01/06/politics/january-6-capitol-riot/index.html',
#   'headline': '<strong>Analysis: </strong>What a reporter trapped in the Capitol on Jan. 6 will always remember about that day',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/211119115714-angry-white-men-angry-captiol-riot-010621-file-small-11.jpg',
#   'duration': '',
#   'description': '<a href="https://www.cnn.com/specials/politics/capitol-riot-investigations" target="_blank"><em>January 6, 2021</em></a><em> started like lots of days on Capitol Hill for CNN reporter </em><a href="https://twitter.com/DaniellaMicaela" target="_blank"><em>Daniella Diaz</em></a><em>. She was braced for a very long day as Congress was set to formalize Joe Biden\'s Electoral College victory. What transpired over the next 21 hours -- rioters storming the US Capitol in an attempted coup -- was history in the making. On the anniversary of that fateful day, I reached out to Daniella to talk about her recollections -- and what memories have stayed with her. Our conversation -- conducted via email and lightly edited for flow -- is below.</em>',
#   'layout': ''},
#  {'uri': '/videos/politics/2022/01/06/dick-cheney-liz-cheney-only-gop-january-6-house-floor-nr-sot-vpx.cnn',
#   'headline': 'Dick Cheney slams GOP over January 6th',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220106143222-dick-cheney-2015-file-small-11.jpeg',
#   'duration': '01:32',
#   'description': "Former Republican Vice President Dick Cheney and his daughter Rep. Liz Cheney (R-WY) were the only two Republicans on the House floor during a remembrance of the January 6th riot. CNN's Manu Raju reports.",
#   'layout': '',
#   'iconType': 'video'},
#  {'uri': '/videos/us/2022/01/05/january-6-children-of-rioters-teen-vogue-fortesa-latifi-newday-vpx.cnn',
#   'headline': 'Teen who called FBI on his dad before Capitol riot speaks to writer',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/210321231141-capitol-hill-riot-0106-small-11.jpg',
#   'duration': '03:01',
#   'description': 'Fortesa Latifi, a "Teen Vogue" contributor, joins New Day to discuss her article about children of rioters who attacked the Capitol building on January 6, 2021. ',
#   'layout': '',
#   'iconType': 'video'},
#  {'uri': '/2022/01/05/opinions/january-6-anniversary-voting-rights-allred/index.html',
#   'headline': '<strong>Opinion: </strong>The text I sent my wife inside the Capitol',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220104115624-january-6-riot-file-2021-small-11.jpg',
#   'duration': '',
#   'description': 'On January 6, I woke up knowing it was going to be a difficult day, but I had no idea that it would take the harrowing turn that it did. ',
#   'layout': ''},
#  {'uri': '/2022/01/06/media/jan-6-anniversary-right-wing-conspiracy-lies/index.html',
#   'headline': 'How right-wing media is marking the Jan. 6 anniversary',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220104235037-sean-hannity-file-02282019-small-11.jpg',
#   'duration': '',
#   'description': '',
#   'layout': ''},
#  {'uri': '/2022/01/06/politics/january-6-insurrection-legacy/index.html',
#   'headline': '<strong>Analysis</strong>: January 6 may be only a preview of a deeper democratic rupture',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220106062045-file-capitol-010621-restricted-small-11.jpg',
#   'duration': '',
#   'description': '',
#   'layout': ''},
#  {'uri': '/2022/01/05/politics/jimmy-carter-democracy-jan-6-oped/index.html',
#   'headline': "Carter warns America 'teeters on the brink of a widening abyss' in stark op-ed",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220105191200-jimmy-carter-file-2018-small-11.jpg',
#   'duration': '',
#   'description': '<a href="https://www.cnn.com/2013/01/08/us/jimmy-carter---fast-facts/index.html" target="_blank">Former President Jimmy Carter</a> warned Wednesday that democracy is being threatened throughout the country, cautioning that "our great nation now teeters on the brink of a widening abyss." ',
#   'layout': ''},
#  {'uri': '/videos/politics/2022/01/06/jake-tapper-republicans-january-6-democracy-newday-vpx.cnn',
#   'headline': "See Jake Tapper's plea to Republicans",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220106090428-jake-tapper-newday-01062022-small-11.jpeg',
#   'duration': '03:06',
#   'description': "CNN's Jake Tapper calls on leaders in the Republican party to stand up for democracy in the United States.",
#   'layout': '',
#   'iconType': 'video'},
#  {'uri': '/2022/01/06/politics/cheney-pence-january-6/index.html',
#   'headline': "Cheney: Jan. 6 committee 'looks forward to' cooperation from Pence",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220105134039-05-jan-6-committee-pivotal-year-cheney-small-11.jpg',
#   'duration': '',
#   'description': '',
#   'layout': ''},
#  {'uri': '/2022/01/04/opinions/voter-restrictions-trump-big-lie-coates/index.html',
#   'headline': '<strong>Opinion: </strong>The bigger lie threatening US democracy',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/211103083741-elections-voting-small-11.jpg',
#   'duration': '',
#   'description': 'There\'s an even bigger lie than the so-called "<a href="https://www.cnn.com/2021/09/16/politics/trump-big-lie-gop-election/index.html" target="_blank">Big Lie</a>" that we don\'t have fair and free elections in this country -- and perhaps one that is even more dangerous to our democracy.',
#   'layout': ''},
#  {'uri': '/2022/01/06/politics/lindsey-graham-biden-jan-6-insurrection-speech/index.html',
#   'headline': "<strong>Analysis</strong>: Lindsey Graham's unreal response to Joe Biden's January 6 speech",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/210802175054-01-lindsey-graham-0730-small-11.jpg',
#   'duration': '',
#   'description': 'In the moments after President Joe Biden <a href="https://www.cnn.com/2022/01/06/politics/january-6-anniversary/index.html" target="_blank">concluded his speech</a> commemorating the one-year anniversary of the January 6 riot at the US Capitol, South Carolina Sen. Lindsey Graham leapt at the chance to offer his own response.',
#   'layout': ''},
#  {'uri': '/2022/01/06/politics/elaine-luria-reelection-announcement/index.html',
#   'headline': 'Jan. 6 panel member launches reelection bid amid backdrop of insurrection anniversary',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220105134038-06-jan-6-committee-pivotal-year-luria-small-11.jpg',
#   'duration': '',
#   'description': 'Rep. Elaine Luria, a Democrat from Virginia and a member of the House committee investigating the Capitol Riot, announced on the anniversary of the attack that she will run for reelection in her Virginia Beach swing district. ',
#   'layout': ''},
#  {'uri': '/2022/01/06/us/dzhokhar-tsarnaev-boston-bomber-covid-stimulus/index.html',
#   'headline': "US Attorney's office requests Boston Marathon bomber to turn over funds",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220106150124-boston-marathon-bomber-covid-relief-check-file-041513-small-11.jpg',
#   'duration': '',
#   'description': "Boston Marathon bomber Dzhokhar Tsarnaev should turn over money to his victims, including a previously deposited $1,400 federal stimulus payment, the US Attorney's Office of Massachusetts said in a filing Wednesday morning.",
#   'layout': ''},
#  {'uri': '/videos/politics/2022/01/06/what-does-marjorie-taylor-greene-do-all-day-cillizza-the-point.cnn',
#   'headline': 'What does Marjorie Taylor Greene do during the day?',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220106112737-the-point-marjorie-taylor-greene-small-11.jpg',
#   'duration': '06:02',
#   'description': 'Controversial Republican Congresswoman and frequent tweeter Marjorie Taylor Greene has been "permanently suspended" from Twitter, raising the question -- what else does she actually do all day, besides engage on the social media site? In the latest episode of The Point, CNN\'s Chris Cillizza unpacks everything Taylor Greene has contributed to Congress so far and how, despite it all, she is still winning the branding game.',
#   'layout': '',
#   'iconType': 'video'},
#  {'uri': '/2022/01/06/weather/snow-storm-warning-advisory-forecast-thursday/index.html',
#   'headline': "A winter storm is hitting from Mississippi to Maine. Here's what to expect",
#   'thumbnail': '',
#   'duration': '',
#   'description': 'Winter weather alerts stretched from coast to coast Thursday with over 100 million people impacted as multiple storm systems are forecast to move across the US over the next 48 hours.',
#   'layout': ''},
#  {'uri': '/videos/media/2022/01/06/carl-cameron-sean-hannity-texts-sot-ac360-vpx.cnn',
#   'headline': "Ex-Fox reporter reacts to Hannity's texts",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220105222118-carl-cameron-small-11.jpeg',
#   'duration': '01:35',
#   'description': "Former Fox reporter Carl Cameron reacts to Sean Hannity's text message released from the January 6 committee, and the lack of response from his former colleague on the matter. ",
#   'layout': '',
#   'iconType': 'video'},
#  {'uri': '/2022/01/06/world/red-supergiant-star-supernova-scn/index.html',
#   'headline': 'Giant dying star explodes as scientists watch in real time — a first for astronomy',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220106111824-red-supergiant-star-supernova-small-11.jpg',
#   'duration': '',
#   'description': 'The death of a star is one of the most dramatic and violent events in space -- and astronomers had an unprecedented front-row seat to the explosive end of a stellar giant.',
#   'layout': ''},
#  {'uri': '/videos/world/2022/01/05/north-korea-weapons-capability-sfc-lon-orig.cnn',
#   'headline': "What's the damage North Korea's weapons do?\ufeff",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/211019210637-north-korea-missile-launch-1019-small-11.jpg',
#   'duration': '02:22',
#   'description': "North Korea's weapons and missile tests have become more sophisticated over the years. CNN's Paula Hancocks looks at some of the country's main weapons and the damage they can do.",
#   'layout': '',
#   'iconType': 'video'},
#  {'uri': '/2022/01/06/business/fresca-alcoholic-drink-launch/index.html',
#   'headline': "One of Coke's most popular sodas is becoming a boozy beverage",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220106083313-fresca-soda-file-restricted-small-11.jpg',
#   'duration': '',
#   'description': 'Coca-Cola is tapping into the <a href="https://www.cnn.com/2021/08/10/business/hard-mountain-dew-launch/index.html" target="_blank">canned cocktail craze</a> with a boozy version of its Fresca soda.',
#   'layout': ''},
#  {'uri': '/travel/article/airline-passengers-partying-canada-sunwing/index.html',
#   'headline': '<strong>Partying passengers stuck in Mexico after airlines decline to fly them home</strong>',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220106110412-sunwing-plane-toronto-121621-restricted-small-11.jpg',
#   'duration': '',
#   'description': 'Some members of a rowdy group shown dancing, drinking and vaping maskless aboard a flight to Cancun find themselves stranded in Mexico after their return flight to Canada was scrubbed and other airlines have declined to fly them home.',
#   'layout': ''},
#  {'uri': '/2022/01/06/politics/republican-sen-ron-johnson-covid-vaccine-god/index.html',
#   'headline': "<strong>Analysis: </strong>What this Republican Senator doesn't know about Covid-19 is, well, a lot",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/210802183234-ron-johnson-dc-statehood-hearing-small-11.jpg',
#   'duration': '',
#   'description': 'Wisconsin Republican Sen. Ron Johnson has made a name for himself as one of the least well-informed elected officials during the nearly two years that the world has been battling the Covid-19 pandemic.',
#   'layout': ''},
#  {'uri': '/videos/opinions/2022/01/05/se-cupp-unfiltered-covid-fatigue-vpx.cnn',
#   'headline': 'SE Cupp: Covid-19 messaging is exhausting us all',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220105113139-se-cupp-1-5-small-11.jpg',
#   'duration': '05:45',
#   'description': 'In this week\'s episode of "Unfiltered," CNN\'s SE Cupp talks Covid-19 fatigue as cases of Omicron surge across the country and families are facing confusing CDC guidelines. ',
#   'layout': '',
#   'iconType': 'video'},
#  {'uri': '/2022/01/06/economy/business-jobs-workers-omicron/index.html',
#   'headline': 'America calls out sick',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220105151518-01-neirs-tavern-small-11.jpg',
#   'duration': '',
#   'description': 'Montclair Bread Co. closed last weekend after a quarter of the staff tested positive for Covid-19. The bakery missed out on 25% of its monthly sales.',
#   'layout': ''},
#  {'uri': '/2022/01/06/entertainment/wicked-elphaba-broadway-actor-returns-covid-cec/index.html',
#   'headline': "An actor returned to Broadway after 7 years to save 'Wicked' from a cast shortage",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220106123446-01-carla-stickler-file-small-11.jpg',
#   'duration': '',
#   'description': 'With the Covid-19 surge fueled by the Omicron variant disrupting numerous Broadway productions, one former Broadway actor recently stepped in to save the day.',
#   'layout': ''},
#  {'uri': '/2022/01/06/health/us-coronavirus-thursday/index.html',
#   'headline': "An 'awful' month of Covid-19 lies ahead, doctor says, but preventative measures will still be key",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220106012140-massachusetts-covid-hospital-12292021-restricted-small-11.jpg',
#   'duration': '',
#   'description': 'While the highly transmissible Omicron variant continues to drive up Covid-19 <a href="https://www.cnn.com/2022/01/04/health/us-coronavirus-tuesday/index.html" target="_blank">cases and hospitalizations</a> -- and the numbers are likely to get worse before they get better -- health experts say it\'s critical Americans continue safe practices to prevent infections.',
#   'layout': ''},
#  {'uri': '/2022/01/06/entertainment/emma-watson-emma-roberts-harry-potter/index.html',
#   'headline': "<strong>Emma Watson responds to 'Harry Potter' reunion mix up with Emma Roberts</strong> ",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220106094003-02-emma-watson-emma-roberts-split-small-11.jpg',
#   'duration': '',
#   'description': 'Emma Watson is taking a Emma Roberts photo snafu in stride.',
#   'layout': ''},
#  {'uri': '/2022/01/06/entertainment/ozark-season-4-trailer/index.html',
#   'headline': "The 'Ozark' Season 4 trailer delivers the goods",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/211229215828-01-new-jan-streaming-2022-ozark-s4-p1-small-11.jpg',
#   'duration': '',
#   'description': 'Netflix\'s "Ozark"<a href="https://www.cnn.com/2017/07/20/tv-shows/ozark-review/index.html" target="_blank"> is back</a> for Seaon 4. ',
#   'layout': ''},
#  {'uri': '/2022/01/06/entertainment/betty-white-funeral/index.html',
#   'headline': "Betty White's funeral will be private, but you can still celebrate her life",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/211231153757-02-betty-white-animal-activism-small-11.jpg',
#   'duration': '',
#   'description': 'The service arrangements for Betty White will be private, her friend and agent Jeff Witjas told CNN Thursday.',
#   'layout': ''},
#  {'uri': '/style/article/the-one-megamansion-bel-air-auction/index.html',
#   'headline': 'LA megamansion could sell for $295 million',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220104182858-06-most-expensive-home-los-angeles-auction-small-11.jpg',
#   'duration': '',
#   'description': 'A 105,000-square-foot mansion in Bel Air, dubbed "The One," could become the most expensive property to sell in the United States when it hits the auction block next month. ',
#   'layout': ''},
#  {'uri': '/style/article/hoyeon-jung-vogue-february-cover-cec/index.html',
#   'headline': "'Squid Game' star is the first Korean to appear solo on the cover of Vogue",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220106120304-squid-game-vogue-cover-010622-small-11.jpg',
#   'duration': '',
#   'description': 'The past few months have been a whirlwind for Hoyeon Jung.',
#   'layout': ''},
#  {'uri': '/videos/business/2022/01/06/bmw-color-changing-technology-orig.cnn-business',
#   'headline': 'This BMW color-changing concept SUV will mess with your head',
#   'thumbnail': '',
#   'duration': '00:53',
#   'description': 'BMW unveiled this color-changing technology that lets a vehicle to go from black to white within seconds.',
#   'layout': '',
#   'iconType': 'video'},
#  {'uri': '/travel/article/car-tips-winter-weather-wellness/index.html',
#   'headline': 'What to pack in your car to stay safe during severe winter weather ',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220106143550-snow-car-preparedness-restricted-small-11.jpg',
#   'duration': '',
#   'description': "If you're ever stranded in your car due to a bad winter storm -- like many Virginians were this week -- being prepared can be the difference between survival and serious harm or death. ",
#   'layout': ''},
#  {'uri': '/travel/article/preet-chandi-completes-south-pole-expedition-idnty/index.html',
#   'headline': '<strong>British Sikh Army officer becomes first woman of color to ski solo to the South Pole</strong>',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220103123301-07b-preet-chandi-small-11.jpg',
#   'duration': '',
#   'description': 'British-born Sikh army officer Preet Chandi has become the first woman of color to complete a solo expedition to the South Pole',
#   'layout': ''},
#  {'uri': '/travel/article/worlds-safest-airlines-2022/index.html',
#   'headline': "The world's safest airline for 2022 revealed",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220103091210-worlds-safest-airlines-2022-small-11.jpg',
#   'duration': '',
#   'description': "Covid-19 has continued to dominate conversations around air safety, leading to some significant changes in airline safety and product review website AirlineRatings.com's annual list.",
#   'layout': ''},
#  {'uri': '/2022/01/05/asia/south-korea-f-35-fighter-jet-belly-landing-intl-hnk-ml/index.html',
#   'headline': '$100M warplane lands with wheels retracted',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220104231726-south-korea-f35a-file-03192019-small-11.jpg',
#   'duration': '',
#   'description': 'The pilot of a South Korean F-35A jet fighter made an emergency "belly landing" at an air base on Tuesday after its landing gear malfunctioned due to electronic issues, a South Korean Air Force spokesperson said.',
#   'layout': ''},
#  {'uri': '/2022/01/05/media/duchess-of-sussex-mail-on-sunday-case-intl-gbr/index.html',
#   'headline': 'Meghan to receive confidential sum from UK newspaper for copyright infringement',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220105124813-meghan-markle-duchess-of-sussex-0925-file-restricted-small-11.jpg',
#   'duration': '',
#   'description': '<a href="http://www.cnn.com/2018/04/16/europe/meghan-markle-fast-facts/index.html" target="_blank">Meghan, Duchess of Sussex</a> will receive a confidential sum from the Mail on Sunday for infringement of copyright as her <a href="https://www.cnn.com/2021/11/12/europe/royal-news-newsletter-11-12-21-scli-gbr-cmd-intl/index.html" target="_blank">lengthy legal battle </a>against the British tabloid comes to an end, court documents show.',
#   'layout': ''},
#  {'uri': '/style/article/architecture-projects-in-2022/index.html',
#   'headline': 'The striking architecture projects set to shape the world in 2022',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220103124923-05-anticipated-architecture-2022-small-11.jpg',
#   'duration': '',
#   'description': 'With <a href="https://www.cnn.com/specials/world/coronavirus-outbreak-intl-hnk" target="_blank">Covid-19</a> causing delays in construction schedules and project openings, compiling CNN\'s annual architecture lookahead has become a tricky business. Indeed, several entries in <a href="https://www.cnn.com/style/article/anticipated-buildings-2021/index.html" target="_blank">last year\'s</a> list (and <a href="https://www.cnn.com/style/article/anticipated-buildings-2020/index.html" target="_blank">even 2020\'s</a>) are yet to officially open their doors. ',
#   'layout': ''},
#  {'uri': '/travel/article/shark-bite-mark-photo/index.html',
#   'headline': "'Never seen such a huge shark scar:' Photographer shares image with mysterious bite mark",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220105130730-shark-bite-crop-small-11.jpg',
#   'duration': '',
#   'description': 'Photographer Jalil Najafov\'s first thought when he saw the great white was: "Is that real?"',
#   'layout': ''},
#  {'uri': '/2022/01/05/entertainment/gal-gadot-imagine-video-intl-scli/index.html',
#   'headline': "Gal Gadot says controversial 'Imagine' video was in 'poor taste'",
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220105103551-gal-gadot-imagine-intl-scli-file-small-11.jpg',
#   'duration': '',
#   'description': '<a href="https://www.cnn.com/2020/05/16/entertainment/gal-gadot-graduation-special-trnd/index.html" target="_blank">Gal Gadot</a> has kicked off 2022 by thoroughly addressing the controversial, <a href="https://www.cnn.com/2020/03/19/celebrities/gal-gadot-celebrities-imagine-coronavirus-scli-intl/index.html" target="_blank">star-studded "Imagine" video</a> that went viral for all the wrong reasons at the start of the global pandemic.',
#   'layout': ''},
#  {'uri': '/2022/01/05/sport/antonio-brown-bucs-injury-statement-nfl-spt/index.html',
#   'headline': 'Antonio Brown says Buccaneers fired him for having a painful ankle injury before he left mid-game',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/220105223655-02-antonio-brown-bucs-jets-01022022-small-11.jpg',
#   'duration': '',
#   'description': 'Tampa Bay Buccaneers wide receiver Antonio Brown said Wednesday he was fired "for having a painful injury" during a game Sunday.',
#   'layout': ''},
#  {'uri': '/2022/01/06/health/creative-workout-motivation-wellness/index.html',
#   'headline': '6 creative ways to transform your workouts',
#   'thumbnail': '//cdn.cnn.com/cnnnext/dam/assets/211228091834-04-update-workouts-wellness-small-11.jpg',
#   'duration': '',
#   'description': 'Most people know working out is good for your health, both physical and mental. But staying motivated -- especially for the long haul -- can be a struggle. Sure, you may get excited about training for a 5K or 10K, but once the race is over, your interest in running may quickly wane. Or you may be crazy about your new spin class, only to become tired of it after a few weeks.',
#   'layout': ''}]

# %% [markdown]
# Data science folks may also want to use this data in pandas! It's easy from here to export to CSV.

# %%
import pandas as pd

# %%
cnn_df = pd.json_normalize(data)
cnn_df # use .to_csv() for CSV exporting
# Out:
#                                                   uri  \
# 0   /2022/01/06/politics/joe-biden-january-6-speec...
# 1   /2022/01/06/politics/january-6-anniversary/ind...
# 2   /videos/politics/2022/01/06/stephanie-grisham-...
# 3   /2022/01/06/opinions/what-i-saw-on-january-6-c...
# 4   /2022/01/06/politics/stephanie-grisham-trump-o...
# 5   /2022/01/06/opinions/president-biden-speech-de...
# 6   /2022/01/06/politics/trump-tweet-january-6/ind...
# 7   /videos/politics/2022/01/06/senator-joe-neguse...
# 8   /2022/01/06/politics/january-6-capitol-riot/in...
# 9   /videos/politics/2022/01/06/dick-cheney-liz-ch...
# 10  /videos/us/2022/01/05/january-6-children-of-ri...
# 11  /2022/01/05/opinions/january-6-anniversary-vot...
# 12  /2022/01/06/media/jan-6-anniversary-right-wing...
# 13  /2022/01/06/politics/january-6-insurrection-le...
# 14  /2022/01/05/politics/jimmy-carter-democracy-ja...
# 15  /videos/politics/2022/01/06/jake-tapper-republ...
# 16  /2022/01/06/politics/cheney-pence-january-6/in...
# 17  /2022/01/04/opinions/voter-restrictions-trump-...
# 18  /2022/01/06/politics/lindsey-graham-biden-jan-...
# 19  /2022/01/06/politics/elaine-luria-reelection-a...
# 20  /2022/01/06/us/dzhokhar-tsarnaev-boston-bomber...
# 21  /videos/politics/2022/01/06/what-does-marjorie...
# 22  /2022/01/06/weather/snow-storm-warning-advisor...
# 23  /videos/media/2022/01/06/carl-cameron-sean-han...
# 24  /2022/01/06/world/red-supergiant-star-supernov...
# 25  /videos/world/2022/01/05/north-korea-weapons-c...
# 26  /2022/01/06/business/fresca-alcoholic-drink-la...
# 27  /travel/article/airline-passengers-partying-ca...
# 28  /2022/01/06/politics/republican-sen-ron-johnso...
# 29  /videos/opinions/2022/01/05/se-cupp-unfiltered...
# 30  /2022/01/06/economy/business-jobs-workers-omic...
# 31  /2022/01/06/entertainment/wicked-elphaba-broad...
# 32  /2022/01/06/health/us-coronavirus-thursday/ind...
# 33  /2022/01/06/entertainment/emma-watson-emma-rob...
# 34  /2022/01/06/entertainment/ozark-season-4-trail...
# 35  /2022/01/06/entertainment/betty-white-funeral/...
# 36  /style/article/the-one-megamansion-bel-air-auc...
# 37  /style/article/hoyeon-jung-vogue-february-cove...
# 38  /videos/business/2022/01/06/bmw-color-changing...
# 39  /travel/article/car-tips-winter-weather-wellne...
# 40  /travel/article/preet-chandi-completes-south-p...
# 41  /travel/article/worlds-safest-airlines-2022/in...
# 42  /2022/01/05/asia/south-korea-f-35-fighter-jet-...
# 43  /2022/01/05/media/duchess-of-sussex-mail-on-su...
# 44  /style/article/architecture-projects-in-2022/i...
# 45   /travel/article/shark-bite-mark-photo/index.html
# 46  /2022/01/05/entertainment/gal-gadot-imagine-vi...
# 47  /2022/01/05/sport/antonio-brown-bucs-injury-st...
# 48  /2022/01/06/health/creative-workout-motivation...
#
#                                              headline  \
# 0   <strong>It's likely to be the line repeated mo...
# 1       Biden condemns Trump as a threat to democracy
# 2   Ex-Trump aide describes the worry with Trump's...
# 3   <strong>Opinion:</strong> I was there on Janua...
# 4   Stephanie Grisham says group of ex-Trump offic...
# 5   <strong>Opinion</strong>: Biden assumes role o...
# 6   <strong>Trump did not want to tweet 'stay peac...
# 7       Senator shares defining moment from January 6
# 8   <strong>Analysis: </strong>What a reporter tra...
# 9              Dick Cheney slams GOP over January 6th
# 10  Teen who called FBI on his dad before Capitol ...
# 11  <strong>Opinion: </strong>The text I sent my w...
# 12  How right-wing media is marking the Jan. 6 ann...
# 13  <strong>Analysis</strong>: January 6 may be on...
# 14  Carter warns America 'teeters on the brink of ...
# 15              See Jake Tapper's plea to Republicans
# 16  Cheney: Jan. 6 committee 'looks forward to' co...
# 17  <strong>Opinion: </strong>The bigger lie threa...
# 18  <strong>Analysis</strong>: Lindsey Graham's un...
# 19  Jan. 6 panel member launches reelection bid am...
# 20  US Attorney's office requests Boston Marathon ...
# 21  What does Marjorie Taylor Greene do during the...
# 22  A winter storm is hitting from Mississippi to ...
# 23          Ex-Fox reporter reacts to Hannity's texts
# 24  Giant dying star explodes as scientists watch ...
# 25       What's the damage North Korea's weapons do?﻿
# 26  One of Coke's most popular sodas is becoming a...
# 27  <strong>Partying passengers stuck in Mexico af...
# 28  <strong>Analysis: </strong>What this Republica...
# 29   SE Cupp: Covid-19 messaging is exhausting us all
# 30                             America calls out sick
# 31  An actor returned to Broadway after 7 years to...
# 32  An 'awful' month of Covid-19 lies ahead, docto...
# 33  <strong>Emma Watson responds to 'Harry Potter'...
# 34    The 'Ozark' Season 4 trailer delivers the goods
# 35  Betty White's funeral will be private, but you...
# 36         LA megamansion could sell for $295 million
# 37  'Squid Game' star is the first Korean to appea...
# 38  This BMW color-changing concept SUV will mess ...
# 39  What to pack in your car to stay safe during s...
# 40  <strong>British Sikh Army officer becomes firs...
# 41       The world's safest airline for 2022 revealed
# 42         $100M warplane lands with wheels retracted
# 43  Meghan to receive confidential sum from UK new...
# 44  The striking architecture projects set to shap...
# 45  'Never seen such a huge shark scar:' Photograp...
# 46  Gal Gadot says controversial 'Imagine' video w...
# 47  Antonio Brown says Buccaneers fired him for ha...
# 48         6 creative ways to transform your workouts
#
#                                             thumbnail duration  \
# 0   //cdn.cnn.com/cnnnext/dam/assets/220106093419-...
# 1   //cdn.cnn.com/cnnnext/dam/assets/220106092029-...
# 2   //cdn.cnn.com/cnnnext/dam/assets/220106091107-...    01:50
# 3   //cdn.cnn.com/cnnnext/dam/assets/220106052132-...
# 4   //cdn.cnn.com/cnnnext/dam/assets/200407100829-...
# 5   //cdn.cnn.com/cnnnext/dam/assets/220106093511-...
# 6   //cdn.cnn.com/cnnnext/dam/assets/220106084508-...
# 7   //cdn.cnn.com/cnnnext/dam/assets/210210131744-...    01:54
# 8   //cdn.cnn.com/cnnnext/dam/assets/211119115714-...
# 9   //cdn.cnn.com/cnnnext/dam/assets/220106143222-...    01:32
# 10  //cdn.cnn.com/cnnnext/dam/assets/210321231141-...    03:01
# 11  //cdn.cnn.com/cnnnext/dam/assets/220104115624-...
# 12  //cdn.cnn.com/cnnnext/dam/assets/220104235037-...
# 13  //cdn.cnn.com/cnnnext/dam/assets/220106062045-...
# 14  //cdn.cnn.com/cnnnext/dam/assets/220105191200-...
# 15  //cdn.cnn.com/cnnnext/dam/assets/220106090428-...    03:06
# 16  //cdn.cnn.com/cnnnext/dam/assets/220105134039-...
# 17  //cdn.cnn.com/cnnnext/dam/assets/211103083741-...
# 18  //cdn.cnn.com/cnnnext/dam/assets/210802175054-...
# 19  //cdn.cnn.com/cnnnext/dam/assets/220105134038-...
# 20  //cdn.cnn.com/cnnnext/dam/assets/220106150124-...
# 21  //cdn.cnn.com/cnnnext/dam/assets/220106112737-...    06:02
# 22
# 23  //cdn.cnn.com/cnnnext/dam/assets/220105222118-...    01:35
# 24  //cdn.cnn.com/cnnnext/dam/assets/220106111824-...
# 25  //cdn.cnn.com/cnnnext/dam/assets/211019210637-...    02:22
# 26  //cdn.cnn.com/cnnnext/dam/assets/220106083313-...
# 27  //cdn.cnn.com/cnnnext/dam/assets/220106110412-...
# 28  //cdn.cnn.com/cnnnext/dam/assets/210802183234-...
# 29  //cdn.cnn.com/cnnnext/dam/assets/220105113139-...    05:45
# 30  //cdn.cnn.com/cnnnext/dam/assets/220105151518-...
# 31  //cdn.cnn.com/cnnnext/dam/assets/220106123446-...
# 32  //cdn.cnn.com/cnnnext/dam/assets/220106012140-...
# 33  //cdn.cnn.com/cnnnext/dam/assets/220106094003-...
# 34  //cdn.cnn.com/cnnnext/dam/assets/211229215828-...
# 35  //cdn.cnn.com/cnnnext/dam/assets/211231153757-...
# 36  //cdn.cnn.com/cnnnext/dam/assets/220104182858-...
# 37  //cdn.cnn.com/cnnnext/dam/assets/220106120304-...
# 38                                                       00:53
# 39  //cdn.cnn.com/cnnnext/dam/assets/220106143550-...
# 40  //cdn.cnn.com/cnnnext/dam/assets/220103123301-...
# 41  //cdn.cnn.com/cnnnext/dam/assets/220103091210-...
# 42  //cdn.cnn.com/cnnnext/dam/assets/220104231726-...
# 43  //cdn.cnn.com/cnnnext/dam/assets/220105124813-...
# 44  //cdn.cnn.com/cnnnext/dam/assets/220103124923-...
# 45  //cdn.cnn.com/cnnnext/dam/assets/220105130730-...
# 46  //cdn.cnn.com/cnnnext/dam/assets/220105103551-...
# 47  //cdn.cnn.com/cnnnext/dam/assets/220105223655-...
# 48  //cdn.cnn.com/cnnnext/dam/assets/211228091834-...
#
#                                           description layout iconType
# 0                                                                 NaN
# 1   <a href="https://www.cnn.com/specials/politics...             NaN
# 2   Stephanie Grisham, former communications direc...           video
# 3   On January 6, 2021, I left the Maryland suburb...             NaN
# 4   Former White House press secretary <a href="ht...             NaN
# 5   President Joe Biden, marking the anniversary o...             NaN
# 6                                                                 NaN
# 7   Sen. Joe Neguse (D-CO) joins Inside Politics t...           video
# 8   <a href="https://www.cnn.com/specials/politics...             NaN
# 9   Former Republican Vice President Dick Cheney a...           video
# 10  Fortesa Latifi, a "Teen Vogue" contributor, jo...           video
# 11  On January 6, I woke up knowing it was going t...             NaN
# 12                                                                NaN
# 13                                                                NaN
# 14  <a href="https://www.cnn.com/2013/01/08/us/jim...             NaN
# 15  CNN's Jake Tapper calls on leaders in the Repu...           video
# 16                                                                NaN
# 17  There's an even bigger lie than the so-called ...             NaN
# 18  In the moments after President Joe Biden <a hr...             NaN
# 19  Rep. Elaine Luria, a Democrat from Virginia an...             NaN
# 20  Boston Marathon bomber Dzhokhar Tsarnaev shoul...             NaN
# 21  Controversial Republican Congresswoman and fre...           video
# 22  Winter weather alerts stretched from coast to ...             NaN
# 23  Former Fox reporter Carl Cameron reacts to Sea...           video
# 24  The death of a star is one of the most dramati...             NaN
# 25  North Korea's weapons and missile tests have b...           video
# 26  Coca-Cola is tapping into the <a href="https:/...             NaN
# 27  Some members of a rowdy group shown dancing, d...             NaN
# 28  Wisconsin Republican Sen. Ron Johnson has made...             NaN
# 29  In this week's episode of "Unfiltered," CNN's ...           video
# 30  Montclair Bread Co. closed last weekend after ...             NaN
# 31  With the Covid-19 surge fueled by the Omicron ...             NaN
# 32  While the highly transmissible Omicron variant...             NaN
# 33  Emma Watson is taking a Emma Roberts photo sna...             NaN
# 34  Netflix's "Ozark"<a href="https://www.cnn.com/...             NaN
# 35  The service arrangements for Betty White will ...             NaN
# 36  A 105,000-square-foot mansion in Bel Air, dubb...             NaN
# 37  The past few months have been a whirlwind for ...             NaN
# 38  BMW unveiled this color-changing technology th...           video
# 39  If you're ever stranded in your car due to a b...             NaN
# 40  British-born Sikh army officer Preet Chandi ha...             NaN
# 41  Covid-19 has continued to dominate conversatio...             NaN
# 42  The pilot of a South Korean F-35A jet fighter ...             NaN
# 43  <a href="http://www.cnn.com/2018/04/16/europe/...             NaN
# 44  With <a href="https://www.cnn.com/specials/wor...             NaN
# 45  Photographer Jalil Najafov's first thought whe...             NaN
# 46  <a href="https://www.cnn.com/2020/05/16/entert...             NaN
# 47  Tampa Bay Buccaneers wide receiver Antonio Bro...             NaN
# 48  Most people know working out is good for your ...             NaN

# %%
# End wall-timing of web scraping workflow
end = time.time()
print(format(end - start, '.4f'), "seconds")
# Out:
# 0.2963 seconds
